# %%
import pandas as pd
import numpy as np
import os

# %%
basics_url="https://datasets.imdbws.com/title.basics.tsv.gz"
akas_url = "https://datasets.imdbws.com/title.akas.tsv.gz"
ratings_url = "https://datasets.imdbws.com/title.ratings.tsv.gz"

# %%
basics_df = pd.read_csv(basics_url,sep='\t', low_memory=False)

# %%
akas_df = pd.read_csv(akas_url,sep='\t', low_memory=False)

# %%
ratings_df = pd.read_csv(ratings_url,sep='\t', low_memory=False)

# %% [markdown]
# **Title Basics**

# %%
# Replace "\N" with np.nan
basics_df.replace({'\\N':np.nan},inplace=True)

# %%
# Drop movies that are missing values for runtimeMinutes, genres, startYear
basics_df = basics_df.dropna(subset = ['runtimeMinutes', 'genres', 'startYear'])

# %%
# Keep titleType movie
basics_df = basics_df.loc[basics_df['titleType'] == 'movie']

# %%
# Keep startYear 2000-2022
basics_df['startYear'] = basics_df['startYear'].astype(int)
basics_df = basics_df.loc[(basics_df['startYear'] >= 2000) & (basics_df['startYear'] <=2021)]

# %%
# Exclude movies that are included in the documentary category.
is_documentary = basics_df['genres'].str.contains('Documentary',case=False)
basics_df = basics_df[~is_documentary]

# %%
basics_df.head(5)
# Out:
#           tconst titleType                                       primaryTitle  \
# 34805  tt0035423     movie                                     Kate & Leopold
# 61119  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 67672  tt0069049     movie                         The Other Side of the Wind
# 77968  tt0079644     movie                                      November 1828
# 86806  tt0088751     movie                                  The Naked Monster
#
#                                    originalTitle isAdult  startYear endYear  \
# 34805                             Kate & Leopold       0       2001     NaN
# 61119  El Tango del Viudo y Su Espejo Deformante       0       2020     NaN
# 67672                 The Other Side of the Wind       0       2018     NaN
# 77968                              November 1828       0       2001     NaN
# 86806                          The Naked Monster       0       2005     NaN
#
#       runtimeMinutes                  genres
# 34805            118  Comedy,Fantasy,Romance
# 61119             70                   Drama
# 67672            122                   Drama
# 77968            140               Drama,War
# 86806            100    Comedy,Horror,Sci-Fi

# %%
# Make directory
os.makedirs('Data/',exist_ok=True)

# %%
# Confirm creation 
os.listdir("Data/")
# Out:
# ['.title_akas.csv.gz.icloud',
#  'title_ratings 2.csv.gz',
#  'title_basics.csv.gz',
#  'title_akas 2.csv.gz',
#  '.title_ratings.csv.gz.icloud',
#  'title_akas.csv.gz',
#  'title_ratings.csv.gz']

# %%
# Open saved file and preview again
basics_df = pd.read_csv("Data/title_basics.csv.gz", low_memory=False)
basics_df.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0079644     movie                                      November 1828
# 4  tt0088751     movie                                  The Naked Monster
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                              November 1828        0       2001      NaN
# 4                          The Naked Monster        0       2005      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             140               Drama,War
# 4             100    Comedy,Horror,Sci-Fi

# %% [markdown]
# **Title Ratings**

# %%
ratings_df.replace({'\\N':np.nan})
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1879
# 1        tt0000002            5.9       248
# 2        tt0000003            6.5      1652
# 3        tt0000004            5.8       161
# 4        tt0000005            6.2      2478
# ...            ...            ...       ...
# 1242536  tt9916690            6.5         6
# 1242537  tt9916720            5.2       209
# 1242538  tt9916730            8.7         6
# 1242539  tt9916766            6.7        19
# 1242540  tt9916778            7.2        34
#
# [1242541 rows x 3 columns]

# %%
ratings_df.to_csv("Data/title_ratings.csv.gz", compression='gzip', index=False)

# %%
# Open saved file and preview again
ratings_df = pd.read_csv("Data/title_ratings.csv.gz", low_memory=False)
ratings_df.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1879
# 1  tt0000002            5.9       248
# 2  tt0000003            6.5      1652
# 3  tt0000004            5.8       161
# 4  tt0000005            6.2      2478

# %%
akas_df = akas_df.loc[akas_df['region'] =='US']

# %%
akas_df.replace({'\\N':np.nan},inplace=True)

# %%
akas_df.to_csv("Data/title_akas.csv.gz", compression='gzip', index=False)

# %%
# Open saved file and preview again
akas_df = pd.read_csv("Data/title_akas.csv.gz", low_memory=True)
akas_df.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes  isOriginalTitle
# 0                    NaN              0.0
# 1  literal English title              0.0
# 2                    NaN              0.0
# 3                    NaN              0.0
# 4                    NaN              0.0

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
us_filter = basics_df['tconst'].isin(akas_df['titleId'])
us_filter
# Out:
# 0          True
# 1          True
# 2          True
# 3         False
# 4          True
#           ...
# 135736     True
# 135737     True
# 135738    False
# 135739     True
# 135740    False
# Name: tconst, Length: 135741, dtype: bool

# %%
basics_df = basics_df[us_filter]
basics_df
# Out:
#            tconst titleType  \
# 0       tt0035423     movie
# 1       tt0062336     movie
# 2       tt0069049     movie
# 4       tt0088751     movie
# 7       tt0093119     movie
# ...           ...       ...
# 135734  tt9914942     movie
# 135735  tt9915872     movie
# 135736  tt9916170     movie
# 135737  tt9916190     movie
# 135739  tt9916362     movie
#
#                                              primaryTitle  \
# 0                                          Kate & Leopold
# 1       The Tango of the Widower and Its Distorting Mi...
# 2                              The Other Side of the Wind
# 4                                       The Naked Monster
# 7                                     Grizzly II: Revenge
# ...                                                   ...
# 135734                             Life Without Sara Amat
# 135735                               The Last White Witch
# 135736                                      The Rehearsal
# 135737                                          Safeguard
# 135739                                              Coven
#
#                                     originalTitle  isAdult  startYear  \
# 0                                  Kate & Leopold        0       2001
# 1       El Tango del Viudo y Su Espejo Deformante        0       2020
# 2                      The Other Side of the Wind        0       2018
# 4                               The Naked Monster        0       2005
# 7                        Grizzly II: The Predator        0       2020
# ...                                           ...      ...        ...
# 135734                 La vida sense la Sara Amat        0       2019
# 135735                  My Girlfriend is a Wizard        0       2019
# 135736                                   O Ensaio        0       2019
# 135737                                  Safeguard        0       2020
# 135739                                   Akelarre        0       2020
#
#         endYear  runtimeMinutes                     genres
# 0           NaN             118     Comedy,Fantasy,Romance
# 1           NaN              70                      Drama
# 2           NaN             122                      Drama
# 4           NaN             100       Comedy,Horror,Sci-Fi
# 7           NaN              74      Horror,Music,Thriller
# ...         ...             ...                        ...
# 135734      NaN              74                      Drama
# 135735      NaN              97       Comedy,Drama,Fantasy
# 135736      NaN              51                      Drama
# 135737      NaN              90  Action,Adventure,Thriller
# 135739      NaN              92              Drama,History
#
# [79267 rows x 9 columns]

# %%
## Save dataframe to file
basics_df.to_csv("Data/title_basics.csv.gz", compression='gzip', index=False)

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import StrMethodFormatter
price_fmt = StrMethodFormatter("${x:,.0f}")
sns.set_style('white')

# %%
# Load in the csv.gz's of results for years 2000 and 2001
year_2000_df = pd.read_csv("Data/final_tmdb_data_2000.csv.gz")
year_2001_df = pd.read_csv("Data/final_tmdb_data_2001.csv.gz")

# %%
# Combine years 2000 and 2001 into a single dataframe
tmdb_results_combined_df = year_2000_df.append(year_2001_df)
# Display the tail and head of the combines dataframe
tmdb_results_combined_df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2     tt0113092    0.0                               NaN
# 3     tt0116391    0.0                               NaN
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# ...         ...    ...                               ...
# 1275  tt7797670    0.0                               NaN
# 1276  tt7797790    0.0                               NaN
# 1277  tt8665056    0.0                               NaN
# 1278  tt8795764    0.0                               NaN
# 1279  tt9071078    0.0                               NaN
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  10000000.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN    150000.0
# ...                    ...         ...
# 1275                   NaN         0.0
# 1276                   NaN         0.0
# 1277                   NaN         0.0
# 1278                   NaN         0.0
# 1279                   NaN         0.0
#
#                                                  genres  \
# 0                                                   NaN
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 2              [{'id': 878, 'name': 'Science Fiction'}]
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# ...                                                 ...
# 1275                     [{'id': 27, 'name': 'Horror'}]
# 1276                     [{'id': 27, 'name': 'Horror'}]
# 1277                    [{'id': 37, 'name': 'Western'}]
# 1278                     [{'id': 27, 'name': 'Horror'}]
# 1279                     [{'id': 28, 'name': 'Action'}]
#
#                                                homepage        id  \
# 0                                                   NaN       NaN
# 1                                                   NaN   62127.0
# 2                                                   NaN  110977.0
# 3                                                   NaN  442869.0
# 4                  http://www.wkw-inthemoodforlove.com/     843.0
# ...                                                 ...       ...
# 1275                                                NaN  956214.0
# 1276                                                NaN  956219.0
# 1277  http://skeletoncreekproductions.com/p-movie-br...  885436.0
# 1278  https://www.utahwolf.com/films/coming-soon-new...  871624.0
# 1279    http://www.hkcinemagic.com/en/movie.asp?id=6627  201706.0
#
#      original_language                              original_title  ...  \
# 0                  NaN                                         NaN  ...
# 1                   en                             The Fantasticks  ...
# 2                   en                               For the Cause  ...
# 3                   hi                                        Gang  ...
# 4                   cn                                        花樣年華  ...
# ...                ...                                         ...  ...
# 1275                en  Edmund Kemper Part 2: La Mort C'est La Vie  ...
# 1276                en         Edmund Kemper Part 3: La mort sévit  ...
# 1277                en                        Guns Along The Bravo  ...
# 1278                en                                   New Breed  ...
# 1279                cn                                        致命密函  ...
#
#          revenue  runtime                                   spoken_languages  \
# 0            NaN      NaN                                                NaN
# 1            0.0     86.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2            0.0    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3            0.0    152.0  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...
# 4     12854953.0     99.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
# ...          ...      ...                                                ...
# 1275         0.0     91.0                                                 []
# 1276         0.0     72.0  [{'english_name': 'French', 'iso_639_1': 'fr',...
# 1277         0.0     85.0                                                 []
# 1278         0.0     57.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1279         0.0     90.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
#
#         status                                            tagline  \
# 0          NaN                                                NaN
# 1     Released      Try to remember the first time magic happened
# 2     Released       The ultimate showdown on a forbidden planet.
# 3     Released                                                NaN
# 4     Released  Feel the heat, keep the feeling burning, let t...
# ...        ...                                                ...
# 1275  Released                                                NaN
# 1276  Released                                                NaN
# 1277  Released  Evil came to the Southwest until three blazing...
# 1278  Released                                                NaN
# 1279  Released                                                NaN
#
#                                            title  video  vote_average  \
# 0                                            NaN    NaN           NaN
# 1                                The Fantasticks    0.0           5.4
# 2                                  For the Cause    0.0           4.4
# 3                                           Gang    0.0           0.0
# 4                           In the Mood for Love    0.0           8.1
# ...                                          ...    ...           ...
# 1275  Edmund Kemper Part 2: La Mort C'est La Vie    0.0           0.0
# 1276         Edmund Kemper Part 3: La mort sévit    0.0           0.0
# 1277                        Guns Along The Bravo    0.0           0.0
# 1278                                   New Breed    0.0           0.0
# 1279                              Chinese Heroes    0.0           3.0
#
#      vote_count certification
# 0           NaN           NaN
# 1          21.0           NaN
# 2           7.0           NaN
# 3           0.0           NaN
# 4        1872.0            PG
# ...         ...           ...
# 1275        0.0           NaN
# 1276        0.0           NaN
# 1277        0.0           NaN
# 1278        0.0            NR
# 1279        2.0           NaN
#
# [2478 rows x 26 columns]

# %%
# Save a final merged .csv.gz of all of the tmdb api data 
tmdb_results_combined_df.to_csv("Data/tmdb_results_combined.csv.gz", 
                                compression="gzip", 
                                index=False)

# %%
# Financial information filter
fin_filter = (tmdb_results_combined_df['budget'] > 0) | (tmdb_results_combined_df['revenue'] > 0)
# Create a dataframe of movies with either a positive budget or revenue
tmdb_results_combined_with_fin_res_df = tmdb_results_combined_df.loc[fin_filter].copy()

# %%
# Report the number of movies with either a positive budget or revenue 
fin_movie_count=len(tmdb_results_combined_with_fin_res_df)
print(f'{fin_movie_count} movies had at least some valid financial information.')
# Out:
# 616 movies had at least some valid financial information.

# %%
# Display the value counts for each certification category
tmdb_results_combined_with_fin_res_df['certification'].value_counts()
# Out:
# R        226
# PG-13    130
# PG        35
# NR        17
# G         14
# Name: certification, dtype: int64
